# %%
import pandas as pd

df = pd.DataFrame({'A': range(1, 6),
                    'B': range(10, 0, -2),
                    'C': range(10, 5, -1)})
print(df.query('A > B'))
print(df.query('B == `C C`'))
print(df[df.A > df.B])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.DataFrame({'A': range(1, 6),
#       4                     'B': range(10, 0, -2),
#       5                     'C': range(10, 5, -1)})
#       6 print(df.query('A > B'))
#
# ModuleNotFoundError: No module named 'pandas'
